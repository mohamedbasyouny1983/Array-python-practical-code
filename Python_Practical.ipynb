# %% [markdown]
# # **Data Structures**

# %% [markdown]
# Remove empty strings and numbers from the list
#
# list_with_empty_strings = ['blue', ' ' ,'green', ' ' , 'red', ' ', 'yellow', 'orange', ' ']

# %%
list_with_empty_strings = ['blue', ' ' ,'green', ' ' , 'red', ' ', 'yellow', 'orange', ' ']
list_without_empty_strings = []
for item in list_with_empty_strings:
  if item != " ":
    list_without_empty_strings.append(item)
print(list_without_empty_strings)

# %%
list_with_empty_strings = ['blue', ' ' ,'green', ' ' , 'red', ' ', 'yellow', 'orange', ' ']
list_without_empty_strings = [item for item in list_with_empty_strings if item !=" "  ]
print(list_without_empty_strings)
# Out:
# ['blue', 'green', 'red', 'yellow', 'orange']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# With taken a list , convert it to a string as it shown below:
#
# ![image.png](data:image/png;base64,...)

# %%
list1 = ["[","'", "[","]","]","'",","," ","'hello']"]
list2 = ["'[[hello]]'"]
string1 = "".join([str(x1) for x1 in list1])
string2 = "".join([str(x2) for x2 in list2])
print(string1)
print(string2)
# Out:
# ['[]]', 'hello']
# '[[hello]]'

# %% [markdown]
# Counts the number of occurrences of item 50 from a tuple.
#
# tuple1 = (50, 10, 60, 70, 50,80,50,90,100)

# %%
tuple1 = (50, 10, 60, 70, 50,80,50,90,100)
count = tuple1.count(50)
print("count: ",count)
# Out:
# count:  3

# %% [markdown]
# Write a Python program that accepts a word from the user and reverse it.
#
# example
#
# enter a word: abcd
#
# Reversed : dcba
#
# ![image.png](attachment:image.png)

# %%
string = input("enter a word : ")
x = reversed(string)
Reversed = "".join(x)
print("Reversed :",Reversed)
# Out:
# enter a word : abcd
# Reversed : dcba

# %% [markdown]
# Return a new sorted set of identical items from a given two set
#
# set1 = {10, 20, 30, 40, 50}
#
# set2 = {30, 40, 50, 60, 70}

# %%
set1 = {10, 20, 30, 40, 50}
set2 = {30, 40, 50, 60, 70}
set = set1.intersection(set2)
# set_listed = list(set)
myset = sorted(set)
# myset = set(set_listed)
# for i in set_listed:
#   myset.add(i)
# x = set(set_listed)
# myset = { i for i in set_listed}
# print(x)
print(set)
print(set_listed)
print(myset)
# print myset
# Out:
# {40, 50, 30}
# [30, 40, 50]
# [30, 40, 50]

# %% [markdown]
# Convert two lists into a dictionary
#
# keys = ['Ten', 'Twenty', 'Thirty']
#
# values = [10, 20, 30]

# %%
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]
dict_= dict(zip (keys,values))
print(dict_)
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %% [markdown]
# # **Loops & Conditions**
#
#
# Iterating over lines in a file:
# we have the protein = "vlspadktnv" and we need to print it as
#
# vls vlsp vlspa vlspad ...etc...
#
#
# ![image.png](data:image/png;base64,...)

# %%
protein = "vlspadktnv"
for i in range(3,len(protein)):
    print(protein[:i])
# Out:
# vls
# vlsp
# vlspa
# vlspad
# vlspadk
# vlspadkt
# vlspadktn

# %% [markdown]
#  Ask about the temperature degree. If it is greater than 35 degree, then wear shorts if not wear long pants.

# %%
temp = int(input("enter temperature :"))
def temperature(temp):
  if temp >= 35:
    print("Get some excerise")
  else:
    print("wear long pants")

temperature(temp)
# Out:
# enter temperature :40
# Get some excerise

# %%
temp = int(input("enter temperature :"))
print("Get some excerise") if temp >= 35 else print("wear long pants")
# Out:
# enter temperature :40
# Get some excerise

# %% [markdown]
# consider a loop that counts from 1 to 10 but prints only the odd numbers in that range

# %%
list = []
for i in range (1,11,2):
  list.append(i)
print(list)
# Out:
# [1, 3, 5, 7, 9]

# %%
list = [i for i in range(1,11,2)]
print (list)
# Out:
# [1, 3, 5, 7, 9]

# %% [markdown]
# ## **Functions**
#
# Create a function that print your full name, your age and your collage by using Non-default arguments

# %%
def data(Name,Age,Collage):
  print("Name :%s" %Name)
  print("Age :%d" %Age)
  print("Collage: %s" %Collage)
data("Ahmed",22,"Arts")
# Out:
# Name :Ahmed
# Age :22
# Collage: Arts

# %% [markdown]
# Write a Python program to print the even numbers from a given list
#
# Sample List : [1, 2, 3, 4, 5, 6, 7, 8, 9]
# Expected Result : [2, 4, 6, 8]

# %%
list = []
for i in range (2,11,2):
  list.append(i)
print(list)
# Out:
# [2, 4, 6, 8, 10]

# %% [markdown]
# Create a function showEmployee() in such a way that it should accept employee name, and it’s salary and display both, and if the salary is missing in function call it should show it as 9000

# %%
def employee(no_of_employee):
  global name, salary
  for i in range(no_of_employee):
    name = input("enter name of employee :")
    # salary = input("enter salary: ")
    if True:
      try:
        salary = int(input("enter salary: "))
      except ValueError:
        salary = 9000
    print("Employee: %s Salary is %d" % (name,salary))
employee(3)
# Out:
# enter name of employee :ahmed
# enter salary:
# Employee: ahmed Salary is 9000
# enter name of employee :sayed
# enter salary: 10000
# Employee: sayed Salary is 10000
# enter name of employee :ramez
# enter salary: 11000
# Employee: ramez Salary is 11000

# %% [markdown]
# Write a Python function that takes Infinite number of arguments and print its valuse

# %%
def name(*names):
  for name in names:
    print("Hello %s"%name)

name("ahmed","joe","zaki")
# Out:
# Hello ahmed
# Hello joe
# Hello zaki

# %% [markdown]
# Write a Python function that takes a number as a parameter and check the number is prime or not
#
#
# ![image.png](data:image/png;base64,...)

# %%
num = int(input())
def prime_test(num):
  if num == 1:
    flag = True
  elif num > 1:
    for i in range(2,num):
      if num % i == 0:
        flag = True
        break
      else:
        flag = False
  if flag:
    print("num is not prime")
  else:
    print("num is prime")

prime_test(num)
# Out:
# 13
# num is prime

# %% [markdown]
# Write a function func1() such that it can accept a variable length of  argument and print all arguments value
#
# Sample Input :
#
# ![image.png](data:image/png;base64,...)

# %%
def func1(*numbers):
  for no in numbers:
    print(no)

func1(10,20,30)
# Out:
# 10
# 20
# 30

# %% [markdown]
# Write a Python function that checks whether a passed string is palindrome or not.
# Note: A palindrome is a word, phrase, or sequence that reads the same backward as forward, e.g., madam, radar and level
#
# ![image.png](data:image/png;base64,...)

# %%
# password = "madam"
iteration = 0
def password_test(password):
  iteration = int(len(password)/2 + 1)
  for i in range(iteration):
    if password[i] == password[(-i-1)]:
        flag = True
    else:
        flag = False
        break
  if flag:
    print("password accepted")
  else:
    print("password is not accepted")
password_test("madam")
# Out:
# password accepted

# %% [markdown]
# Write a Python program that takes a string of words and returns the length of the longest one.
#
#
# ![image.png](data:image/png;base64,...)

# %%
input_1 = input('enter word1:')
input_2 = input('enter word2:')
input_3 = input('enter word3:')

len_input_1 = len_input_2 =len_input_3 = 0
flag_1 = flag_2 = flag_3 = 0

def word_max_test(input_1,input_2,input_3):
  global flag_1
  global flag_2
  global flag_3
  len_input_1 = len(input_1)
  len_input_2 = len(input_2)
  len_input_3 = len(input_3)
  if len_input_1 > len_input_2:
    if len_input_1 > len_input_3:
      flag_1 = True
    elif len_input_3 > len_input_1:
      flag_3 = True
  elif len_input_1 < len_input_2:
    if len_input_2 > len_input_3:
      flag_2 = True
    elif len_input_3> len_input_2:
      flag_3 = True

  if flag_1:
    print("word1 is maximum :%s"%input_1)
  if flag_2:
    print("word2 is maximum :%s"%input_2)
  if flag_3:
    print("word3 is maximum :%s"%input_3)

word_max_test(input_1,input_2,input_3)
# Out:
# enter word1:a
# enter word2:aa
# enter word3:aaa
# word3 is maximum :aaa

# %% [markdown]
# Write a Python function to find the Max of three numbers.
#
# ![image.png](data:image/png;base64,...)

# %%
num1 = 3
num2 = 6
num3 = -5
# flag_1 = flag_2 = flag_3 = False
def num_test(num1,num2,num3):
  global flag_1
  global flag_2
  global flag_3
  if num1 > num2:
    if num1 > num3:
      flag_1 = True
    elif num3 > num1:
      flag_3 = True
  elif num1 < num2:
    if num2 > num3:
        flag_2 = True
    elif num3> num2:
        flag_3 = True

  if flag_1:
    print("num1 is maximum :%d"%num1)
  if flag_2:
    print("num2 is maximum :%d"%num2)
  if flag_3:
    print("num3 is maximum :%d"%num3)

num_test(num1,num2,num3)
# Out:
# num2 is maximum :6

# %% [markdown]
# # make a Full calculator

# %%
import math

print("+")
print("-")
print("*")
print("/")
print("1/x")
print("sin")
print("cos")
print("tan")
print("log")
print("ln")
print("log")
print("x!")
print("squroot")
# result = 0
choice = input ("enter calculation method:")
if choice in ("+","-","/","*"):
    print("enter two numbers")
    num1 = float(input("num1:"))
    num2 = float(input("num2:"))
    if choice == "+":
        def sum(num1,num2):
          num1 + num2
        print("num1 + num2 =",num1 + num2 )
#         break
    elif choice =="-":
        def subtract(num1,num2):
          num1 - num2
        print("num1 - num2 =",num1 - num2 )
    elif choice =="/":
        def div(num1,num2):
          num1 / num2
        print("num1 / num2 =",num1 / num2 )
    elif choice =="*":
        def mul(num1,num2):
          num1 * num2
        print("num1 * num2 =",num1 * num2 )
    else:
        print("Invalid input")

elif choice in ("1/x","log","ln","x!","squroot"):
    print("enter one number")
    num = float(input())
    if choice == "1/x":
        def oper(num):
          1/num
        print("1/x =",1/num)
    elif choice =="x!":
        num = int(num)
        def factorial(num):
          math.factorial(num)
        print("!x = ", math.factorial(num))

    elif choice =="squroot":
        def squroot(num):
          math.sqrt(num)
        print("squroot(x) = ", math.sqrt(num))
#         break
    elif choice =="log":
        result = lambda num: math.log10(num)
        print("log(x) = ",result(num))
#         break
    elif choice == "ln":
      def ln(num):
        math.log(num)
      print(" ln(x) = ",math.log(num))
#         break
elif choice in ("sin","cos","tan"):
    num = float(input("enter value from 0 to 360 :"))
    if choice == "sin":
        def sin(num):
          math.sin(math.radians(num))
        print("sin(x) = ", math.trunc(math.sin(math.radians(num))))
#         break
    elif choice =="cos":
        def cos(num):
          math.cos(math.radians(num))
        print("cos(x) = ", math.trunc(math.cos(math.radians(num))))
#         break
    elif choice =="tan":
      def tan(num):
        math.tan(math.radians(num))
      print("tan(x) = ", math.trunc(math.tan(math.radians(num))))

#         result = float(res
#         if result > 510:
#             print("infinite result")
#         else:
        # print("tan(x) = ", math.trunc(result(num)))
# Out:
# +
# -
# *
# /
# 1/x
# sin
# cos
# tan
# log
# ln
# log
# x!
# squroot
# enter calculation method:tan
# enter value from 0 to 360 :45
# tan(x) =  0

# %% [markdown]
# write code to draw heart

# %%
import turtle
turtle.title("heart")
pen = turtle.Turtle()
pen.penup()
pen.goto(0,-50)
pen.setheading(60)
pen.pendown()
pen.forward(150)
pen.circle(50,200)
pen.setheading(90)
pen.circle(50,200)
pen.setheading(-52)
pen.forward(190)


turtle.done()

# %% [markdown]
# # *** Enjoy your time while you're Coding 😁***
